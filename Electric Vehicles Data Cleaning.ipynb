# %%
## Importing Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
## Importing the data

df = pd.read_csv("C:/Users/sujay/OneDrive/Desktop/Electric Vehicles Data.csv")
df
# Out:
#         VIN (1-10)        County               City State  Postal Code  \
# 0       KM8K33AGXL          King            Seattle    WA      98103.0
# 1       1C4RJYB61N          King            Bothell    WA      98011.0
# 2       1C4RJYD61P        Yakima             Yakima    WA      98908.0
# 3       5YJ3E1EA7J          King           Kirkland    WA      98034.0
# 4       WBY7Z8C5XJ      Thurston            Olympia    WA      98501.0
# ...            ...           ...                ...   ...          ...
# 150477  WBY43AW05P  Grays Harbor          Montesano    WA      98563.0
# 150478  5YJ3E1EB7P          King            Seattle    WA      98104.0
# 150479  5YJYGDEEXM          King            Seattle    WA      98109.0
# 150480  5UXTA6C08P     Snohomish  Mountlake Terrace    WA      98043.0
# 150481  7SAYGDEF8N        Skagit       Mount Vernon    WA      98273.0
#
#         Model Year     Make           Model  \
# 0             2020  HYUNDAI            KONA
# ...

# %%
## Checking for null values in the data

df.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 3
# City                                                   3
# State                                                  0
# Postal Code                                            3
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 341
# DOL Vehicle ID                                         0
# Vehicle Location                                       7
# Electric Utility                                       3
# ...

# %%
## Dropping columns "Legislative District and 2020 Census Tract" which are not in scope for analysis

new_df = df.drop(["Legislative District","2020 Census Tract"],axis = 1)

# %%
## Retreiving columns

new_df.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'DOL Vehicle ID', 'Vehicle Location', 'Electric Utility'],
#       dtype='object')

# %%
## Filling null values in the columns with Not Available

new_df[["County","City","Postal Code","Vehicle Location","Electric Utility"]]=df[["County","City","Postal Code","Vehicle Location","Electric Utility"]].fillna("Not Available")

# %%
## Checking for null values in the new data frame

new_df.isna().sum()
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# Electric Utility                                     0
# dtype: int64

# %%
## Checking the shape of the new data frame

new_df.shape
# Out:
# (150482, 15)

# %%
new_df.to_csv("Electric_vehicle_cleaned_data.csv",index = False)
